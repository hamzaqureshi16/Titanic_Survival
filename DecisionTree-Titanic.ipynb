# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

sex_mapping = {'male': 0.0, 'female': 1.0}
train_data['Sex'] = train_data['Sex'].map(sex_mapping)
test_data['Sex'] = test_data['Sex'].map(sex_mapping)


train_data.dropna(axis=0)
test_data.dropna(axis=0)
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
selected_features = ["Pclass","Age","Fare","Sex"]
X_train = train_data[selected_features]
X_test = test_data[selected_features]

 
y_train = train_data["Survived"]

X_train["Age"].fillna(X_train["Age"].mean(), inplace=True)
X_test["Age"].fillna(X_test["Age"].mean(), inplace=True)
X_test["Fare"].fillna(X_test["Fare"].mean(), inplace=True)
# Out:
# C:\Users\Mhamz\AppData\Local\Temp\ipykernel_38584\2235478727.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["Age"].fillna(X_train["Age"].mean(), inplace=True)
# C:\Users\Mhamz\AppData\Local\Temp\ipykernel_38584\2235478727.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["Age"].fillna(X_test["Age"].mean(), inplace=True)
# C:\Users\Mhamz\AppData\Local\Temp\ipykernel_38584\2235478727.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
titanic_model = DecisionTreeRegressor(random_state=1)
titanic_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
y_predict = titanic_model.predict(X_test)

print(X_test)
# Out:
#      Pclass       Age      Fare  Sex
# 0         3  34.50000    7.8292  0.0
# 1         3  47.00000    7.0000  1.0
# 2         2  62.00000    9.6875  0.0
# 3         3  27.00000    8.6625  0.0
# 4         3  22.00000   12.2875  1.0
# ..      ...       ...       ...  ...
# 413       3  30.27259    8.0500  0.0
# 414       1  39.00000  108.9000  1.0
# 415       3  38.50000    7.2500  0.0
# 416       3  30.27259    8.0500  0.0
# 417       3  30.27259   22.3583  0.0
#
# [418 rows x 4 columns]

# %%
pred =  {'Pclass': [1],'Age': [95],'Fare': [5], 'Sex': [1]}
mydf = pd.DataFrame(pred)

mypred = titanic_model.predict(mydf)

print(mypred)
# Out:
# [1.]
